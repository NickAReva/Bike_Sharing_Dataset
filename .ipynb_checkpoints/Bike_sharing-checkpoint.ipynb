# %% [markdown]
# ## О датасете

# %% [markdown]
# Датасет представляет собой два набора данных сервиса аренды велосипедов. Наборы содержат данные по дням и часам соответственно. Данные взяты из журнала записей за 2 года - 2011 и 2012 годы.
#
# Предполагается, что процесс аренды велосипедов тесно связан с окружающей средой и сезонными условиями. Например, погодные условия,
# осадки, день недели, сезон, время суток и т.д., которыее могут влиять на поведение клиентов при аренде.

# %% [markdown]
# ### Глава 1. Подготовка данных
# #### 1.1. Импорт набора данных
# #### 1.2. Обзор набора данных
# #### 1.3. Удаление пропущенных значений и выбросов
# #### 1.3.1. Обнаружение выбросов
# #### 1.3.2. Устранение пропущенных значений
# #### 1.3.3. Устранение выбросов
# ### Глава 2. EDA
# ### Глава 3. Моделирование
# #### 3.1.  Нормализация
# #### 3.2. Алгоритм K-Means
# #### 3.3. Метрики оценки
# ### Глава 4. Результаты
# #### 4.1. Визуализация результатов
# #### 4.2. Столбчатая и круговая диаграммы

# %% [markdown]
# Описание параметров датасетов:
#
# Both hour.csv and day.csv have the following fields, except hr which is not available in day.csv
#
# 	- instant: record index
# 	- dteday : date
# 	- season : season (1:springer, 2:summer, 3:fall, 4:winter)
# 	- yr : year (0: 2011, 1:2012)
# 	- mnth : month ( 1 to 12)
# 	- hr : hour (0 to 23)
# 	- holiday : weather day is holiday or not (extracted from http://dchr.dc.gov/page/holiday-schedule)
# 	- weekday : day of the week
# 	- workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# 	+ weathersit :
# 		- 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 		- 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 		- 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 		- 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# 	- temp : Normalized temperature in Celsius. The values are divided to 41 (max)
# 	- atemp: Normalized feeling temperature in Celsius. The values are divided to 50 (max)
# 	- hum: Normalized humidity. The values are divided to 100 (max)
# 	- windspeed: Normalized wind speed. The values are divided to 67 (max)
# 	- casual: count of casual users
# 	- registered: count of registered users
# 	- cnt: count of total rental bikes including both casual and registered

# %% [markdown]
# ### Импортируем необходимые библиотеки

# %%
# установим библиотеки
import pandas as pd
import numpy as np

# Matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# Internal python tool for setting figure size
from IPython.core.pylabtools import figsize

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns',  16)

# %% [markdown]
# # 1. Подготовка данных

# %% [markdown]
# Анализ данных: Исследуйте сезонные и временные паттерны в данных о прокате велосипедов. Постройте графики зависимости спроса на велосипеды от погодных условий, времени суток и дня недели

# %% [markdown]
# ## 1.1.	Импорт данных

# %% [markdown]
# Загрузим данные по дням

# %%
df_day = pd.read_csv('data/day.csv')

# %% [markdown]
# Загрузим данные по часам

# %%
df_hour = pd.read_csv('data/hour.csv')

# %% [markdown]
# ## 1.2.	Обзор данных

# %% [markdown]
# ### Типы и характеристики данных

# %% [markdown]
# Выведем наименования параметров, их количество, тип, количество уникальных значений, дубликатов и пропущеных значений и их процент. Сначала по дневным данным

# %%
df_day_info = pd.DataFrame({
    "DataType": df_day.dtypes,
    "UniqueValues": df_day.nunique(),
    "Duplicated": df_day.duplicated().sum(),
    "MissingValues": df_day.isnull().sum(),
}).sort_values(by="MissingValues", ascending=False)

df_day_info['MissingValuesRatio'] = round(df_day_info['MissingValues'] / len(df_day_info),2)

df_day_info
# Out:
#            DataType  UniqueValues  Duplicated  MissingValues  \
# instant       int64           731           0              0
# dteday       object           731           0              0
# season        int64             4           0              0
# yr            int64             2           0              0
# mnth          int64            12           0              0
# holiday       int64             2           0              0
# weekday       int64             7           0              0
# workingday    int64             2           0              0
# weathersit    int64             3           0              0
# temp        float64           499           0              0
# atemp       float64           690           0              0
# hum         float64           595           0              0
# windspeed   float64           650           0              0
# casual        int64           606           0              0
# ...

# %% [markdown]
# Теперь по часовым

# %%
df_hour_info = pd.DataFrame({
    "DataType": df_hour.dtypes,
    "UniqueValues": df_hour.nunique(),
    "Duplicated": df_hour.duplicated().sum(),
    "MissingValues": df_hour.isnull().sum(),
}).sort_values(by="MissingValues", ascending=False)

df_hour_info['MissingValuesRatio'] = round(df_hour_info['MissingValues'] / len(df_hour_info),2)

df_hour_info
# Out:
#            DataType  UniqueValues  Duplicated  MissingValues  \
# instant       int64         17379           0              0
# weathersit    int64             4           0              0
# registered    int64           776           0              0
# casual        int64           322           0              0
# windspeed   float64            30           0              0
# hum         float64            89           0              0
# atemp       float64            65           0              0
# temp        float64            50           0              0
# workingday    int64             2           0              0
# dteday       object           731           0              0
# weekday       int64             7           0              0
# holiday       int64             2           0              0
# hr            int64            24           0              0
# mnth          int64            12           0              0
# ...

# %% [markdown]
# Разница в количестве параметров: в часовых добавился параметр - час (hr), в количестве записей - 17379 против 731.

# %% [markdown]
# На первый взгляд ни там ни там пропусков нет. Но посмотрим описательную статистику. Поступим немного нестандартно, посмотрим разницу описательных статистик. Просто возьмем и вычтем из часовой дневную. Удалим только столбец hr в часовой

# %%
df_hour.drop(['hr'], axis = 1).describe() - df_day.describe()
# Out:
#             instant        season            yr          mnth       holiday  \
# count  16648.000000  16648.000000  16648.000000  16648.000000  16648.000000
# mean    8324.000000      0.005060      0.001877      0.017940      0.000043
# std     4805.863688     -0.003889     -0.000334     -0.013137      0.000011
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     4162.000000      0.000000      0.000000      0.000000      0.000000
# 50%     8324.000000      0.000000      0.000000      0.000000      0.000000
# 75%    12486.000000      0.000000      0.000000      0.000000      0.000000
# max    16648.000000      0.000000      0.000000      0.000000      0.000000
#
#             weekday    workingday    weathersit          temp         atemp  \
# count  16648.000000  16648.000000  16648.000000  16648.000000  16648.000000
# mean       0.006419     -0.001274      0.029935      0.001602      0.001421
# ...

# %% [markdown]
# Здесь видно, временные характеристики аналогичны для обоих датасетов. Также практически идентичен Тип погоды - weathersit. А вот погодные условия - температура, влажность, ветер имеют отличия в дневном и часовом датасетах.

# %% [markdown]
# Пропусков нет, переходим к следующей части

# %% [markdown]
# ### Распределение целевой переменной

# %% [markdown]
# Примем нашей целевой переменной столбец 'cnt': общее количество арендованных велосипедов как зарегистрированными, так и случайными клиентами.
# Посмотрим распределение дневного датасета

# %%
figsize(12, 4)
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
sns.set_context("paper", rc={"font.size":10,"axes.titlesize":10,"axes.labelsize":10})

# Гистограмма по количеству арендованных велосипедов
sns.histplot(data=df_day, x="cnt", bins = 50).set(xlabel = 'Количество заказов в день', ylabel = 'Частота', title = 'Распределение заказов в день')
plt.show()

# %% [markdown]
# Распределение отдаденно напоминает нормальное. Есть некоторые выбросы в начале и конце. На минимуме, возможно это были случайные арендаторы в "нелетную" погоду. В конце видимо какие то праздники с экстримальным количеством арендаторов.

# %% [markdown]
# И часовой датасет

# %%
figsize(12, 4)

# Гистограмма по количеству арендованных велосипедов
sns.histplot(data=df_hour, x="cnt", bins = 50).set(xlabel = 'Количество заказов в час', ylabel = 'Частота', title = 'Распределение заказов в час')
plt.show()

# %% [markdown]
# Распределение напоминает экспотенциальное. Видно, что в большинстве случаев количество не превышает 200, что подтверждается описательной статистикой выше (там 50% - это 142). Отдельно нужно проверить "хвост" на выбросы и аномальность.

# %% [markdown]
# ### Выбросы и аномальные значения

# %% [markdown]
# Построим графики распределения по нашим переменным. Начнем с дневного датасета

# %% [markdown]
# **Дневной датасет**

# %%
# уберем из рассмотрения лишние данные, такие как instant - номер записи, dteday - дата, workingday - рабочий день, holiday - праздники и yr - год.
df_day_for_plot = df_day.drop(columns = ['instant', 'dteday', 'holiday', 'workingday', 'yr'])
plt.subplots(nrows=2 , ncols=6 , figsize=(20,12))
for i in range (len(df_day_for_plot.columns)):
    plt.subplot(2,6,i+1)
    sns.boxplot(df_day_for_plot[df_day_for_plot.columns[i]], color='aqua')

plt.show()

# %% [markdown]
# Ожидаемо, что временные характеристики (сезон, месяц, день недели) не имеют вопросов. Есть некоторые вопросы по влажности (hum) и скорости ветра (windspeed).

# %% [markdown]
# **Часовой датасет**

# %%
# уберем из рассмотрения лишние данные, такие как instant - номер записи, dteday - дата, workingday - рабочий день, holiday - праздники и yr - год.
df_hour_for_plot = df_hour.drop(columns = ['instant', 'dteday', 'holiday', 'workingday', 'yr'])
plt.subplots(nrows=2 , ncols=6 , figsize=(20,12))
for i in range (len(df_hour_for_plot.columns)):
    plt.subplot(2,6,i+1)
    sns.boxplot(df_hour_for_plot[df_hour_for_plot.columns[i]], color='aqua')

plt.show()

# %% [markdown]
# Ситуация аналогична с дневным. Хотя по влажности здесь все более ровно.

# %% [markdown]
# **Дневной датасет**
#
# Посмотрим "нижнюю" границу в нашем дневном датасете

# %%
df_day.loc[df_day['cnt'] == 22, :]
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 667      668  2012-10-29       4   1    10        0        1           1
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 667           3  0.44  0.4394  0.88     0.3582       2          20   22

# %% [markdown]
# 29 октября, легкий снег или дождь, видимо действительно "экстрималы". Проверим описание без данного значения

# %%
df_day[df_day['cnt'] > 22]['cnt'].describe()
# Out:
# count     730.000000
# mean     4510.489041
# std      1931.408300
# min       431.000000
# 25%      3169.750000
# 50%      4548.500000
# 75%      5966.000000
# max      8714.000000
# Name: cnt, dtype: float64

# %% [markdown]
# Нижняя граница сдвинулась на 431, это довольно много. Это явно аномальное значение.
#
# Теперь проверим верхнюю границу. Однако учитывая, что по графику видно несколько значений. Выведем "хвост" отсортированного списка

# %%
df_day['cnt'].sort_values(ascending=False).head(10)
# Out:
# 623    8714
# 637    8555
# 630    8395
# 447    8362
# 504    8294
# 617    8227
# 571    8173
# 629    8167
# 643    8156
# 518    8120
# Name: cnt, dtype: int64

# %% [markdown]
# Видно, что 2(два) верхних значения отстоят от остальной выборки.
# Для чистоты эксперимента удалим "экстримальные значения сверху и снизу.

# %%
# Обозначим минимум второе минимальное значение
min_ = df_day['cnt'].sort_values(ascending=True).iloc[1]
# Обозначим максимум второе максимальное значение
max_ = df_day['cnt'].sort_values(ascending=False).iloc[1]
# Удалим значения вне диапазона
df_day = df_day[(df_day['cnt'] > min_) & (df_day['cnt'] < max_)]
#выведем описания для проверки
df_day.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  727.000000  727.000000  727.000000  727.000000  727.000000  727.000000
# mean   365.321871    2.493810    0.499312    6.515818    0.028886    2.990371
# std    210.615073    1.109514    0.500344    3.450470    0.167601    2.002386
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.000000    2.000000    0.000000    7.000000    0.000000    3.000000
# 75%    546.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  727.000000  727.000000  727.000000  727.000000  727.000000  727.000000
# mean     0.685007    1.394773    0.495654    0.474522    0.627756    0.190231
# ...

# %% [markdown]
# **Часовой датасет**
#
# Посмотрим "верхнюю" границу в нашем часовом датасете

# %%
df_hour['cnt'].sort_values(ascending=False).head(20)
# Out:
# 14773    977
# 14964    976
# 14748    970
# 14725    968
# 15084    967
# 15780    963
# 10622    957
# 15108    953
# 15444    948
# 15588    943
# 14293    941
# 15756    938
# 14772    925
# 15732    922
# 15276    917
# 13596    913
# 15132    905
# 15300    901
# 15324    900
# 14965    900
# Name: cnt, dtype: int64

# %% [markdown]
# На первый взгляд вроде бы все гармонично, но интересно, что индексы рядом друг с другом. Проверим, что это было

# %%
df_hour.loc[df_hour['cnt'] >= 900, :].sort_values(by='cnt', ascending=False)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  ...  \
# 14773    14774  2012-09-12       3   1     9  18        0        3  ...
# 14964    14965  2012-09-20       3   1     9  17        0        4  ...
# 14748    14749  2012-09-11       3   1     9  17        0        2  ...
# 14725    14726  2012-09-10       3   1     9  18        0        1  ...
# 15084    15085  2012-09-25       4   1     9  17        0        2  ...
# 15780    15781  2012-10-24       4   1    10  17        0        3  ...
# 10622    10623  2012-03-23       2   1     3  17        0        5  ...
# 15108    15109  2012-09-26       4   1     9  17        0        3  ...
# 15444    15445  2012-10-10       4   1    10  17        0        3  ...
# 15588    15589  2012-10-16       4   1    10  17        0        2  ...
# 14293    14294  2012-08-23       3   1     8  18        0        4  ...
# 15756    15757  2012-10-23       4   1    10  17        0        2  ...
# ...

# %% [markdown]
# Аномалий нет. Дни не выходные. Все натурально. Кстати можно заметить следующие закономерности - год 1, то есть это второй год работы сервиса, время 17-18 часов, и погодные условия почти все 1 (ясно, тепло). Выводы конечно буду делать позже, но здесь можно предположить, что сервис раскрутился и боьшинство клиентов любят покататься после работы в хорошую погоду.

# %% [markdown]
# ##

# %% [markdown]
# ## 1.2. Исследовательский анализ данных (EDA - Exploratory data analysis):
# Исследуем сезонные и временные паттерны в данных о прокате велосипедов. Построим графики зависимости спроса на велосипеды от погодных условий, времени суток и дня недели.

# %% [markdown]
# ### Зависимости от сезона, месяца, дня недели

# %% [markdown]
# Исследуйте сезонные и временные паттерны в данных о прокате велосипедов. Постройте графики зависимости спроса на велосипеды от погодных условий, времени суток и дня недели

# %% [markdown]
# **Сезон и месяцы**
#
# Посмотрим зависимость от сезона и месяца обоих датасетов

# %%
figsize(12, 6)
fig, axes = plt.subplots(2, 2)
sns.set_context("paper", rc={"font.size":10,"axes.titlesize":10,"axes.labelsize":10})

sns.barplot(data=df_day, x = 'season', y='cnt', hue = 'season', legend=False, ax=axes[0,0], palette='dark').set(xlabel = 'Сезон', ylabel = 'Кол-во заказов')
sns.barplot(data=df_hour, x ='season', y='cnt', hue = 'season', legend=False, ax=axes[0,1], palette='dark').set(xlabel = 'Сезон', ylabel = 'Кол-во заказов')
sns.barplot(data=df_day, x ='mnth', y='cnt', hue = 'mnth', legend=False, ax=axes[1,0], palette='dark').set(xlabel = 'Месяцы', ylabel = 'Кол-во заказов')
sns.barplot(data=df_hour, x ='mnth', y='cnt', hue = 'mnth', legend=False, ax=axes[1,1], palette='dark').set(xlabel = 'Месяцы', ylabel = 'Кол-во заказов')

fig.suptitle('Зависимость среднего количества заказов от сезона и месяца')
plt.tight_layout()
plt.show()

# %% [markdown]
# Видно, что имеется четкая зависимость от сезона и месяца, причем она аналогична как для дневного так и для часового датасетов.

# %% [markdown]
# **Дни недели**
#
# Построим графики по зависимости от дня недели и от того праздничный ли день или нет.

# %%
figsize(12, 6)
fig, axes = plt.subplots(2, 2)
#sns.set_context("paper", rc={"font.size":10,"axes.titlesize":10,"axes.labelsize":10})

sns.barplot(data=df_day, x = 'weekday', y='cnt', hue = 'weekday', legend=False, ax=axes[0,0], palette='dark').set(xlabel = 'День недели', ylabel = 'Кол-во заказов')
sns.barplot(data=df_hour, x ='weekday', y='cnt', hue = 'weekday', legend=False, ax=axes[0,1], palette='dark').set(xlabel = 'День недели', ylabel = 'Кол-во заказов')
sns.barplot(data=df_day, x = 'weekday', y='cnt', hue = 'holiday', legend=False, ax=axes[1,0], palette='dark').set(xlabel = 'День недели/праздник', ylabel = 'Кол-во заказов')
sns.barplot(data=df_hour, x ='weekday', y='cnt', hue = 'holiday', legend=False, ax=axes[1,1], palette='dark').set(xlabel = 'День недели/праздник', ylabel = 'Кол-во заказов')

fig.suptitle('Зависимость среднего количества от дня недели и праздничных дней')
plt.tight_layout()
plt.show()

# %% [markdown]
# Видно что распределение по "обычным" дням недели почти равномерно. Также видно что праздники не приходятся на понедельники и воскресения. А также видно, что количество заказов очень зависит от того на какой день недели выпадает праздник. Если он попадает на среду, количество заказов по сравнению с обычным днем увеличивается, если на другие дни то уменьшается.
#
# График с праздничными днями для часового датасета имееет отличия от дневного.

# %% [markdown]
# **Часы**
#
# Посмотрим распределение по часам с дополнительным разделением по типу дня.

# %%
figsize(12, 4)

sns.barplot(data=df_hour, x ='hr', y='cnt', hue = 'holiday', legend=True, palette='dark').set(xlabel = 'День недели/праздник', ylabel = 'Кол-во заказов')

plt.show()

# %% [markdown]
# Распределения почти похожи. Однако на распределении для непраздничных дней явно видны всплески в утренние часы с 6 до 9, и в вечерние часы с 16 до 19 часов. Стоит посмотреть подробнее.
#
# Построим график для непраздних дней по часам.

# %%
subset = df_hour[df_hour['holiday'] == 0]
sns.relplot(data = subset, x = 'hr', y = 'cnt', hue = 'weekday', kind = 'line', errorbar=None, palette='dark', height=3, aspect=4).set(xlabel = 'Часы', ylabel = 'Кол-во заказов')
plt.show()

# %% [markdown]
# Как видно из графика в рабочие дни с понедельника (1) по пятницу (5) количество заказов значительно увеличивается по утрам и вечерам, т.е. в нерабочее время.
#
# И для полноты картины построим график для праздничных дней

# %%
subset = df_hour[df_hour['holiday'] == 1]
sns.relplot(data = subset, x = 'hr', y = 'cnt', hue = 'weekday', kind = 'line', errorbar=None, palette='dark', height=3, aspect=4).set(xlabel = 'Часы', ylabel = 'Кол-во заказов')
plt.show()

# %% [markdown]
# Графики для праздничных дней очень схожи с выходными днями. Выбивается из картины среда. Если праздник выпадает на среду, то популярность аренды велосипедов резко возрастает.

# %% [markdown]
# ### Зависимость от погодных условий

# %% [markdown]
# Погодные условия представлены параметрами:
# - тип погоды (weathersit): 1: Ясно, малооблачно; - 2: Пасмурно, облачно; - 3: Легкий снег или дождь; - 4: Сильный дождь или снег, град;
# - температура (temp): нормализованная температура, получена как деление на 41 градус Цельсия, взята как максимум;
# - ощущаемая температура (atemp): aнормализованная температура, получена как деление на 50 градусов Цельсия, взята как максимум;
# - влажность(hum):
#  нормализованная влажность. Значения поделены на 100 (максимум);
# - скорость ветр(windspeed): winнормализована. Поделена на 67 (максимум).67 (max)

# %% [markdown]
# **Тип погоды - weathersit**

# %% [markdown]
# Первый параметр по сути является категориальным признаком, так как представлен всего четырьмя значениями. Построим boxplot чтобы посмотреть как распределяется количество аренд в зависимости от погоды

# %%
figsize(12, 4)
fig, axes = plt.subplots(1, 2)
sns.set_context("paper", rc={"font.size":10,"axes.titlesize":10,"axes.labelsize":10})

sns.barplot(data=df_day, x = 'weathersit', y='cnt', hue = 'weathersit', legend=False, ax=axes[0], palette='dark').set(xlabel = 'Тип погоды', ylabel = 'Кол-во заказов')
sns.barplot(data=df_hour, x = 'weathersit', y='cnt', hue = 'weathersit', legend=False, ax=axes[1], palette='dark').set(xlabel = 'Тип погоды', ylabel = 'Кол-во заказов')

fig.suptitle('Зависимость среднего количества от типа погоды')
plt.tight_layout()
plt.show()

# %% [markdown]
# В целом тренд очевиден, что чем хуже погода, тем меньше желающих покататься на велосипедах. Однако в часовом датасете появляется 4-ый тип погоды. Вероятно, что это связано с резким изменением погоды - день обещал быть хорошим, но внезапный снег или дождь и некоторые не стали изменять свои планы, надеясь на улучшение погоды.

# %% [markdown]
# ### Температура, влажность и ветер

# %% [markdown]
# Посмотрим теперь на графики распределения количества аренд в зависимости от температуры, влажности и скорости ветра. Учитывая, что эти величины непрерывные, то лучше будет построить графики типа scatterplot

# %%
sns.regplot(data = df_hour, x = 'temp', y = 'cnt')
plt.show()

# %%
figsize(14, 8)
fig, axes = plt.subplots(2, 2)
sns.set_context("paper", rc={"font.size":12,"axes.titlesize":10,"axes.labelsize":8})

sns.scatterplot(data=df, x = 'temp', y='cnt', hue = 'weathersit', ax=axes[0,0], palette='tab10').set(xlabel = 'Температура', ylabel = 'Кол-во заказов')
sns.scatterplot(data=df, x = 'atemp', y='cnt', hue = 'weathersit', ax=axes[0,1], palette='tab10').set(xlabel = 'Ощущаемая температура', ylabel = 'Кол-во заказов')
sns.scatterplot(data=df, x = 'hum', y='cnt', hue = 'weathersit', ax=axes[1,0], palette='tab10').set(xlabel = 'Влажность', ylabel = 'Кол-во заказов')
sns.scatterplot(data=df, x = 'windspeed', y='cnt', hue = 'weathersit', ax=axes[1,1], palette='tab10').set(xlabel = 'Скорость ветра', ylabel = 'Кол-во заказов')

fig.suptitle('Зависимость количества заказов от параметров погоды')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Некоторые промежуточные выводы:**
#
# Первое, что хотелось бы отметить - temp atemp сильно коррелированы между собой и соответвенно для модели можно выбрать только один из них.
#
# Второе, очевидно, что чем комфортнее погодные условия, тем больше заказов на аренду. Это касается как температуры, так и влажности и скрор

# %% [markdown]
# ### Проверка изменений по году ведения статистики

# %% [markdown]
# Посмотрим есть ли разница между годами ведения статистики (рост или падение)

# %%
figsize(6, 4)

sns.barplot(data = df, x="yr", y="cnt")
plt.show()

# %% [markdown]
# Видно, что разница есть и у ребят есть весьма хороший рост от года 0 к году 1

# %% [markdown]
# ### Корреляция

# %% [markdown]
# Рассчитаем корреляции исходных параметров относительно нашей целевой переменной

# %%
# уберем лишние колонки не несущие смысла
data = df.drop(['instant', 'dteday', 'casual', 'registered'], axis = 1)
correlations_data = data.corr()['cnt'].sort_values()
print(correlations_data)
# Out:
# weathersit   -0.291733
# windspeed    -0.238235
# hum          -0.090953
# holiday      -0.069291
# weekday       0.057958
# workingday    0.075097
# mnth          0.278868
# season        0.408167
# yr            0.570120
# temp          0.628790
# atemp         0.632407
# cnt           1.000000
# Name: cnt, dtype: float64

# %% [markdown]
# Проверим, не улучшится ли корреляция если мы применим некоторые преобразования к числовым параметрам

# %%
# Создадим колонки к квадратами, корнями и логарифмами
for col in data.columns:
    # пропускаем целевую переменую
    if col == 'cnt':
        next
    else:
        data['sqrt_' + col] = np.sqrt(data[col])
        data['log_' + col] = np.log(data[col])
# Out:
# C:\My_programs\Anaconda\envs\learn\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\My_programs\Anaconda\envs\learn\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\My_programs\Anaconda\envs\learn\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\My_programs\Anaconda\envs\learn\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\My_programs\Anaconda\envs\learn\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# посчитаем корреляцию снова
correlations = data.corr()['cnt'].sort_values()
# выведем первые 10 значений
correlations.head(15)
# Out:
# weathersit        -0.291733
# sqrt_weathersit   -0.285053
# log_weathersit    -0.278646
# windspeed         -0.238235
# sqrt_windspeed    -0.227579
# log_windspeed     -0.209133
# hum               -0.090953
# holiday           -0.069291
# sqrt_holiday      -0.069291
# log_hum           -0.068579
# sqrt_hum          -0.059520
# log_weekday        0.038248
# weekday            0.057958
# sqrt_weekday       0.066630
# sqrt_workingday    0.075097
# Name: cnt, dtype: float64

# %%
# и последние 10 значений
correlations.tail(15)
# Out:
# log_mnth          0.416234
# sqrt_season       0.448443
# log_season        0.483994
# sqrt_yr           0.570120
# yr                0.570120
# temp              0.628790
# atemp             0.632407
# sqrt_temp         0.647599
# sqrt_atemp        0.648618
# log_atemp         0.654462
# log_temp          0.655761
# cnt               1.000000
# log_yr                 NaN
# log_holiday            NaN
# log_workingday         NaN
# Name: cnt, dtype: float64

# %% [markdown]
# Преобразования не изменили значимо отношения. Видно что наша целевая переменная больше всего зависит от температуры, сезона, месяца, типа погоды и ветра.
